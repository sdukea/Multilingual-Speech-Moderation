# %%
import pandas as pd
import matplotlib.pyplot as plt

tr_path = 'D:\\Syon\\Success\\Products\\Speech Moderation - Accesco\\Multilingual-Speech-Moderation\\data\\hindi\\train\\train.csv'
tr = pd.read_csv(tr_path)

val_path = 'D:\\Syon\\Success\\Products\\Speech Moderation - Accesco\\Multilingual-Speech-Moderation\\data\\hindi\\validation.csv'
val = pd.read_csv(val_path)

print(tr.head())
print(val.head())
# Out:
#                                                 text    label
# 0             तभी अगर उन दलितों का कोई गला घोंट देता     hate
# 1  जापान के नोबल पुरस्कार जीतने वाले ओर  साल तक च...     hate
# 2   ने  से अधिक स्टेशनों का सौरकरण किया\n\n स्टेश...  nonhate
# 3                        पाकिस्तानी एक वाइरसहोते हैं     hate
# 4  \n\n पूर्व राष्ट्रपति प्रणब मुखर्जी का लम्बी ब...     hate
#                                                 text    label
# 0       केवल बांग्लादेशी ही इतने हिं स क हो सकते हैं     hate
# 1        दलितों को जाके एक दुसरे की चुदाई करनी चाहिए     hate
# 2  आज मुझे मोदी और राज नाथ पर बहुत गुस्सा आ रहा ह...  nonhate
# 3       जिस तरह एक केजरी के चमचे  एक मार्शल को धक...  nonhate
# 4   के आदेश पर डॉ कफ़ील मथुरा की जेल से ढेर रात क...  nonhate

# %%
print(tr.columns)
print(val.columns)
# Out:
# Index(['text', 'label'], dtype='str')
# Index(['text', 'label'], dtype='str')

# %%
tr.isnull().sum()
val.isnull().sum()
# Out:
# text     0
# label    0
# dtype: int64

# %%
tr['label'].value_counts()
# Out:
# label
# nonhate    5411
# hate       4356
# Name: count, dtype: int64

# %%
tr.duplicated().sum()
# Out:
# np.int64(1)

# %%
# text length for an approximate maximum token length
tr["text"].str.len().describe()
# Out:
# count    9767.000000
# mean      100.875704
# std        74.793187
# min         8.000000
# 25%        46.000000
# 50%        75.000000
# 75%       134.000000
# max       666.000000
# Name: text, dtype: float64

# %%
val['text'].str.len().describe()
# Out:
# count    2442.000000
# mean      100.698608
# std        74.968408
# min        11.000000
# 25%        46.000000
# 50%        74.000000
# 75%       136.000000
# max       636.000000
# Name: text, dtype: float64

# %%
val['label'].value_counts()
# Out:
# label
# nonhate    1296
# hate       1146
# Name: count, dtype: int64

# %%
tr["text"].str.len().hist(bins=40)
# Out:
# <Axes: >

# %%
tr.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 9767 entries, 0 to 9766
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   text    9767 non-null   str
#  1   label   9767 non-null   str
# dtypes: str(2)
# memory usage: 2.6 MB

# %%
val.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 2442 entries, 0 to 2441
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   text    2442 non-null   str
#  1   label   2442 non-null   str
# dtypes: str(2)
# memory usage: 671.6 KB

# %%
val.duplicated().sum()
# Out:
# np.int64(0)
